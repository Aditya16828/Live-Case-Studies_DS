# %%
import pandas as pd
import numpy as np
from datetime import date
import datetime as dt

# %%
uber_df = pd.read_csv('./My Uber Drives - 2016.csv')
uber_df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
uber_df.head(7)
# Out:
#       START_DATE*       END_DATE* CATEGORY*           START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business      Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business      Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business      Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business      Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business      Fort Pierce  West Palm Beach
# 5  1/6/2016 17:15  1/6/2016 17:19  Business  West Palm Beach  West Palm Beach
# 6  1/6/2016 17:30  1/6/2016 17:35  Business  West Palm Beach       Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit
# 5     4.3   Meal/Entertain
# 6     7.1          Meeting

# %%
uber_df.tail(5)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
uber_df.shape
# Out:
# (1156, 7)

# %%
uber_df.size
# Out:
# 8092

# %%
uber_df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
uber_df.notnull().sum()
# Out:
# START_DATE*    1156
# END_DATE*      1155
# CATEGORY*      1155
# START*         1155
# STOP*          1155
# MILES*         1156
# PURPOSE*        653
# dtype: int64

# %%
uber_df['PURPOSE*'].isna().sum()
# Out:
# 503

# %%
# uber_df['PURPOSE*'].notnull().sum()
(~uber_df['PURPOSE*'].isna()).sum()
# Out:
# 653

# %%
def createDict(df):
    list = df.columns
    temp = []
    for i in range(len(list)):
        temp.append(list[i].replace("*", ""))
    return temp

uber_df.columns = createDict(uber_df)
uber_df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
uber_df[uber_df['START'] == 'Fort Pierce']
# Out:
#        START_DATE        END_DATE  CATEGORY        START             STOP  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
uber_df[uber_df['STOP'] == 'Fort Pierce']
# Out:
#        START_DATE        END_DATE  CATEGORY        START         STOP  MILES  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce  Fort Pierce    5.1
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce  Fort Pierce    5.0
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce  Fort Pierce    4.8
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce  Fort Pierce    4.7
#
#            PURPOSE
# 0   Meal/Entertain
# 1              NaN
# 2  Errand/Supplies
# 3          Meeting

# %%
uber_df.sort_values(by= 'MILES', ascending=False)
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# ...                ...               ...       ...               ...
# 1121  12/27/2016 12:53  12/27/2016 12:57  Business           Kar?chi
# 1110  12/24/2016 22:04  12/24/2016 22:09  Business            Lahore
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
#
#                   STOP    MILES          PURPOSE
# 1155               NaN  12204.7              NaN
# ...

# %%
uber_df = uber_df.drop(uber_df[uber_df['STOP'].isna()].index)
uber_df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
uber_df.describe()
# Out:
#              MILES
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %%
unique_start = uber_df['START'].unique()
unique_stop = uber_df['STOP'].unique()

print(unique_start, len(unique_start))
print(unique_stop, len(unique_stop))
# Out:
# ['Fort Pierce' 'West Palm Beach' 'Cary' 'Jamaica' 'New York' 'Elmhurst'
#  'Midtown' 'East Harlem' 'Flatiron District' 'Midtown East'
#  'Hudson Square' 'Lower Manhattan' "Hell's Kitchen" 'Downtown' 'Gulfton'
#  'Houston' 'Eagan Park' 'Morrisville' 'Durham' 'Farmington Woods'
#  'Whitebridge' 'Lake Wellingborough' 'Fayetteville Street' 'Raleigh'
#  'Hazelwood' 'Fairmont' 'Meredith Townes' 'Apex' 'Chapel Hill'
#  'Northwoods' 'Edgehill Farms' 'Tanglewood' 'Preston' 'Eastgate'
#  'East Elmhurst' 'Jackson Heights' 'Long Island City' 'Katunayaka'
#  'Unknown Location' 'Colombo' 'Nugegoda' 'Islamabad' 'R?walpindi'
#  'Noorpur Shahan' 'Heritage Pines' 'Westpark Place' 'Waverly Place'
#  'Wayne Ridge' 'Weston' 'East Austin' 'West University' 'South Congress'
#  'The Drag' 'Congress Ave District' 'Red River District' 'Georgian Acres'
#  'North Austin' 'Coxville' 'Convention Center District' 'Austin' 'Katy'
#  'Sharpstown' 'Sugar Land' 'Galveston' 'Port Bolivar' 'Washington Avenue'
# ...

# %%
uber_df[uber_df['START'] == uber_df['STOP']]
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Kar?chi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
uber_df.value_counts()
# Out:
# START_DATE        END_DATE          CATEGORY  START            STOP              MILES  PURPOSE
# 6/28/2016 23:34   6/28/2016 23:59   Business  Durham           Cary              9.9    Meeting            2
# 1/1/2016 21:11    1/1/2016 21:17    Business  Fort Pierce      Fort Pierce       5.1    Meal/Entertain     1
# 4/15/2016 12:29   4/15/2016 12:32   Business  Meredith Townes  Harden Place      1.4    Errand/Supplies    1
# 4/12/2016 12:22   4/12/2016 12:44   Business  Raleigh          Morrisville       15.9   Meeting            1
# 4/12/2016 13:42   4/12/2016 14:01   Business  Morrisville      Cary              6.5    Meal/Entertain     1
#                                                                                                           ..
# 12/26/2016 13:09  12/26/2016 13:43  Business  Lahore           Unknown Location  7.9    Meeting            1
# 12/26/2016 8:30   12/26/2016 8:41   Business  Lahore           Lahore            3.2    Meal/Entertain     1
# ...

# %%
uber_df[uber_df['START'] == uber_df['STOP']].size
# Out:
# 2016

# %%
uber_df.groupby(by='START', dropna=False).agg({'MILES': 'sum'}).sort_values(by='MILES', ascending=False)
# Out:
#                         MILES
# START
# Unknown Location       1976.5
# Cary                   1791.3
# Morrisville             671.7
# Raleigh                 433.0
# Islamabad               401.2
# ...                       ...
# South Berkeley            0.9
# Congress Ave District     0.8
# Sunnyside                 0.7
# Medical Centre            0.7
# Soho                      0.5
#
# [177 rows x 1 columns]

# %%
uber_df.dtypes
# Out:
# START_DATE     object
# END_DATE       object
# CATEGORY       object
# START          object
# STOP           object
# MILES         float64
# PURPOSE        object
# dtype: object

# %%
uber_df = uber_df.drop(uber_df[(uber_df['STOP'] == 'Unknown Location') & (uber_df['START'] == 'Unknown Location')].index)
uber_df
# Out:
#             START_DATE          END_DATE  CATEGORY        START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business  Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business  Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business  Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business  Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business  Fort Pierce
# ...                ...               ...       ...          ...
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business      Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business      Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business      Kar?chi
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business   Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business      Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# 1          Fort Pierce    5.0              NaN
# 2          Fort Pierce    4.8  Errand/Supplies
# ...

# %%
uber_df['START_DATE'] = pd.to_datetime(uber_df['START_DATE'])
uber_df['END_DATE'] = pd.to_datetime(uber_df['END_DATE'])

# %%
# uber_df
# excelWriter = pd.ExcelWriter('Modified-UberData.xlsx')
# uber_df.to_excel('Modified-UberData.xlsx')

# %%
uber_df.dtypes
# Out:
# START_DATE    datetime64[ns]
# END_DATE      datetime64[ns]
# CATEGORY              object
# START                 object
# STOP                  object
# MILES                float64
# PURPOSE               object
# dtype: object

# %%
grp = uber_df.groupby(by=uber_df['START_DATE'].dt.month).value_counts(['START_DATE'], normalize=True)
grp
# Out:
# START_DATE  START_DATE
# 1           2016-01-02 01:25:00    0.016393
#             2016-01-01 21:11:00    0.016393
#             2016-01-15 13:26:00    0.016393
#             2016-01-27 14:05:00    0.016393
#             2016-01-20 13:25:00    0.016393
#                                      ...
# 12          2016-12-12 13:36:00    0.008130
#             2016-12-12 13:22:00    0.008130
#             2016-12-11 21:48:00    0.008130
#             2016-12-11 19:05:00    0.008130
#             2016-12-31 22:08:00    0.008130
# Length: 1068, dtype: float64

# %%
grp = uber_df.groupby(by=uber_df['START_DATE'].dt.month).count()['START_DATE']
# print(grp)
sum = grp.sum()
grp = grp/sum
grp
# print(sum)
# Out:
# START_DATE
# 1     0.057063
# 2     0.099158
# 3     0.105706
# 4     0.050514
# 5     0.045837
# 6     0.101029
# 7     0.104771
# 8     0.096352
# 9     0.016838
# 10    0.093545
# 11    0.114125
# 12    0.115061
# Name: START_DATE, dtype: float64

# %%
grp = uber_df.groupby(by=uber_df['START_DATE'].dt.month).mean()['MILES']
grp
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_3908\2426530285.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grp = uber_df.groupby(by=uber_df['START_DATE'].dt.month).mean()['MILES']
# START_DATE
# 1      8.408197
# 2      7.557547
# 3     14.990265
# 4     20.611111
# 5      7.424490
# 6      7.803704
# 7     10.933929
# 8      7.114563
# 9     13.583333
# 10    17.226000
# 11     6.695902
# 12     6.300813
# Name: MILES, dtype: float64

# %%
uber_df['START_DATE'].dt.day
# Out:
# 0        1
# 1        2
# 2        2
# 3        5
# 4        6
#         ..
# 1149    30
# 1150    31
# 1151    31
# 1153    31
# 1154    31
# Name: START_DATE, Length: 1069, dtype: int64

# %%
grp2 = uber_df.groupby(by=["CATEGORY", "PURPOSE"]).aggregate({'MILES': np.sum})
grp2
# Out:
#                            MILES
# CATEGORY PURPOSE
# Business Airport/Travel      4.1
#          Between Offices   197.0
#          Customer Visit   2084.2
#          Errand/Supplies   473.8
#          Meal/Entertain    911.7
#          Meeting          2690.2
#          Temporary Site    402.7
# Personal Charity ($)        15.1
#          Commute           180.2
#          Moving             18.2

# %%
grp3 = grp2
grp3['%'] = grp3.groupby(by='CATEGORY', group_keys=False).apply(lambda x: 100 * (x/x.sum()))
grp3
# Out:
#                            MILES          %
# CATEGORY PURPOSE
# Business Airport/Travel      4.1   0.060618
#          Between Offices   197.0   2.912607
#          Customer Visit   2084.2  30.814495
#          Errand/Supplies   473.8   7.005042
#          Meal/Entertain    911.7  13.479309
#          Meeting          2690.2  39.774088
#          Temporary Site    402.7   5.953842
# Personal Charity ($)        15.1   7.072600
#          Commute           180.2  84.402810
#          Moving             18.2   8.524590
